# %% [markdown]
# <a href="https://colab.research.google.com/github/onlyabhilash/Transformers_with_NLP/blob/main/ByT5/Multilexnorm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align="center"><b>ÚFAL at MultiLexNorm 2021:</b></h1>
# <h2 align="center"><b>Improving Multilingual Lexical Normalization by Fine-tuning ByT5</b></h2>
# <br>
#
# <p align="center">
#   <b>David Samuel & Milan Straka</b>
# </p>
#
# <p align="center">
#   <i>
#     Charles University<br>
#     Faculty of Mathematics and Physics<br>
#     Institute of Formal and Applied Linguistics
#   </i>
# </p>
# <br>
#
# <p align="center">
#   <a href="https://aclanthology.org/2021.wnut-1.54/"><b>Paper</b></a><br>
#   <a href="https://github.com/ufal/multilexnorm2021"><b>GitHub repository</b></a>
# </p>

# %% [markdown]
# <p align="center">
#   <img src="https://github.com/ufal/multilexnorm2021/raw/master/img/overall.png" alt="Overall architecture." width="720"/>
# </p>

# %% [markdown]
# # Introduction
#
# This is the official demo notebook for the winning entry to the [*W-NUT 2021: Multilingual Lexical Normalization (MultiLexNorm)* shared task](https://noisy-text.github.io/2021/multi-lexnorm.html), which
# evaluates lexical-normalization systems on 12 social media datasets in 11
# languages.
#
# Our system is based on [ByT5](https://arxiv.org/abs/2105.13626), which we first pre-train on synthetic data and then fine-tune on authentic normalization data. Our system achieves the best performance by a wide margin in intrinsic evaluation, and also the best performance in extrinsic evaluation through dependency parsing. In addition to this notebook, we also release the fine-tuned models on [HuggingFace TODO](TODO) and the source codes on [GitHub](https://github.com/ufal/multilexnorm2021).

# %% [markdown]
# # Interactive demo

# %% [markdown]
# ## 1. Initialize
#
# First, we have to clone the repository, install all required modules, import them and also implement a light-weight AbstractData class that handles new sentences.

# %%
# !git clone https://github.com/ufal/multilexnorm2021
# %cd multilexnorm2021

# !pip3 install torchmetrics==0.4.1
# !pip3 install transformers==4.8.2
# !pip3 install pytorch_lightning==1.3.8

from google.colab import output
from utility.twokenize import tokenizeRawTweetText
import torch
import warnings
import math
warnings.filterwarnings('ignore')

import sys
sys.path.append("/content/multilexnorm2021")

from config.params import Params
from data.dataset.inference import InferenceDataset
from data.inference_data import CollateFunctor
from data.abstract_data import AbstractData
from torch.utils.data import DataLoader
from model.model import Model
from config.params import Params
from utility.output_assembler import OutputAssembler
from pytorch_lightning.utilities.apply_func import move_data_to_device


class Data(AbstractData):
    def __init__(self, inputs, args):
        super().__init__(args)
        self.dataset = InferenceDataset(inputs)
        collate_fn = CollateFunctor(self.tokenizer)

        self.dataloader = DataLoader(
            self.dataset, batch_size=self.batch_size, shuffle=False, num_workers=self.threads, collate_fn=collate_fn
        )


args = Params().load(["--config", "config/inference.yaml"])
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

output.clear()

# %% [markdown]
# ## 2. Write a sentence to be normalized
#
# Please select the language of the sentence youo want to normalize and, most importantly, provide the sentence itself. Don't forget to hit the "run" button afterwards! :)

# %%
language = "en"  #@param ['da', 'de', 'en', 'es', 'hr', 'iden', 'it', 'nl', 'sl', 'sr', 'tr', 'trde']
input = "yo hv to let ppl decide wat dey wanna do" #@param {type:"string"}

args.dataset.language = language
path = f"ufal/byt5-small-multilexnorm2021-{language}"
args.model.pretrained_lm = args.dataset.tokenizer = path

# %% [markdown]
# ## 3. Run!
#
# Automatically downloads the suitable fine-tuned model from Hugging Face and runs the inference. We release the fine-tuned models together with the source code.

# %%
tokens = [tokenizeRawTweetText(input)]

data = Data(tokens, args)
assembler = OutputAssembler(".", args, data.dataset)
model = Model(args, data).to(device)
model.eval()

for i, batch in enumerate(data.dataloader):
    batch = move_data_to_device(batch, device)
    output = model.generate(batch)
    assembler.step(output)

assembler.flush()

with open("outputs.txt") as f:
    words = [w.split('\t')[1].strip() for w in f.readlines() if w != '\n']

output.clear()
print(f"ORIGINAL:   {input}")
print(f"NORMALIZED: {' '.join(words)}")
# Out:
# Downloading:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.59k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/706 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# ORIGINAL:   yo hv to let ppl decide wat dey wanna do
# NORMALIZED: you have to let people decide what they want to do

# %% [markdown]
# ## Addendum: some more options

# %% [markdown]
# ### A. Get more predictions for each word
#
# You can set the number of beams in the config file to get different number of options

# %%
with open("raw_outputs.txt") as f:
    for line in f.readlines():
        original, *options = line.split('\t')
        options = zip(options[::2], options[1::2])

        print(original)
        for i, (word, logprob) in enumerate(options):
            print(f"  {i}: {word} -- with likelihood ~ {math.exp(float(logprob)):.2f}")
        print()
# Out:
# yo
#   0: you -- with likelihood ~ 1.00
#   1: you going to -- with likelihood ~ 0.10
#   2: you will -- with likelihood ~ 0.05
#   3: you have -- with likelihood ~ 0.05
#   4: you gonna -- with likelihood ~ 0.05
#   5: you're -- with likelihood ~ 0.05
#   6: youlugually -- with likelihood ~ 0.04
#   7: youluvely -- with likelihood ~ 0.04
#   8: youluguay -- with likelihood ~ 0.04
#   9: you would -- with likelihood ~ 0.03
#   10: you will have -- with likelihood ~ 0.03
#   11: you will you -- with likelihood ~ 0.03
#   12: you would have -- with likelihood ~ 0.03
#   13: you wasn't -- with likelihood ~ 0.03
#   14: youull -- with likelihood ~ 0.02
#   15: youluve -- with likelihood ~ 0.02
#
# hv
#   0: have -- with likelihood ~ 1.00
#   1: government -- with likelihood ~ 0.05
#   2: gevernment -- with likelihood ~ 0.04
#   3: have announce -- with likelihood ~ 0.02
#   4: have avenue -- with likelihood ~ 0.02
#   5: have average -- with likelihood ~ 0.02
#   6: have've -- with likelihood ~ 0.02
#   7: have fuck -- with likelihood ~ 0.02
#   8: have have -- with likelihood ~ 0.02
#   9: have are -- with likelihood ~ 0.01
#   10: having -- with likelihood ~ 0.01
#   11: have too -- with likelihood ~ 0.01
#   12: average -- with likelihood ~ 0.01
#   13: have avoid -- with likelihood ~ 0.01
#   14: heave -- with likelihood ~ 0.01
#   15: have-too -- with likelihood ~ 0.01
#
# to
#   0: to -- with likelihood ~ 1.00
#   1: to'learning -- with likelihood ~ 0.02
#   2: to'leveloper -- with likelihood ~ 0.02
#   3: to'leaving -- with likelihood ~ 0.02
#   4: together -- with likelihood ~ 0.02
#   5: to'levelopenger -- with likelihood ~ 0.02
#   6: tournament -- with likelihood ~ 0.02
#   7: to'leveloped -- with likelihood ~ 0.01
#   8: to'levelopment -- with likelihood ~ 0.01
#   9: to'leading -- with likelihood ~ 0.01
#   10: to'learnment -- with likelihood ~ 0.01
#   11: to'learned -- with likelihood ~ 0.01
#   12: toking to -- with likelihood ~ 0.01
#   13: to'learning to -- with likelihood ~ 0.01
#   14: tokether -- with likelihood ~ 0.01
#   15: to'leveloping -- with likelihood ~ 0.01
#
# let
#   0: let -- with likelihood ~ 1.00
#   1: let yourself-storylaughing -- with likelihood ~ 0.03
#   2: let yourself-storyline-baseball -- with likelihood ~ 0.03
#   3: let yourself-storyline-between -- with likelihood ~ 0.02
#   4: let yourself-storyline-betweet -- with likelihood ~ 0.02
#   5: let yourself -- with likelihood ~ 0.02
#   6: let yourself-storyline-shortly -- with likelihood ~ 0.02
#   7: let yourself-storyline -- with likelihood ~ 0.02
#   8: let yourself-storyline-short -- with likelihood ~ 0.02
#   9: let yourself-storyline-base-you -- with likelihood ~ 0.02
#   10: let yourself-storyline-based -- with likelihood ~ 0.02
#   11: let yourself-storylause -- with likelihood ~ 0.02
#   12: let yourself-storyline-with -- with likelihood ~ 0.02
#   13: let yourself-storyline-base-yet -- with likelihood ~ 0.02
#   14: let yourself-storyline-base -- with likelihood ~ 0.02
#   15: let yourself-storylight -- with likelihood ~ 0.02
#
# ppl
#   0: people -- with likelihood ~ 1.00
#   1: other people -- with likelihood ~ 0.18
#   2: they'people -- with likelihood ~ 0.16
#   3: other laughing people -- with likelihood ~ 0.15
#   4: speech people -- with likelihood ~ 0.14
#   5: other lot of a lot of -- with likelihood ~ 0.14
#   6: other laughing laughing -- with likelihood ~ 0.13
#   7: other league best people -- with likelihood ~ 0.13
#   8: other lot of -- with likelihood ~ 0.13
#   9: other laughing my people -- with likelihood ~ 0.13
#   10: other laughing -- with likelihood ~ 0.12
#   11: other laughing love -- with likelihood ~ 0.12
#   12: other league boyfriend -- with likelihood ~ 0.12
#   13: other lot of people -- with likelihood ~ 0.11
#   14: open people -- with likelihood ~ 0.11
#   15: other league baseball -- with likelihood ~ 0.11
#
# decide
#   0: decide -- with likelihood ~ 1.00
#   1: decide-becide -- with likelihood ~ 0.07
#   2: decide-conside -- with likelihood ~ 0.06
#   3: decide-concide -- with likelihood ~ 0.06
#   4: decide-contain -- with likelihood ~ 0.06
#   5: decide-forever -- with likelihood ~ 0.06
#   6: decide-secide -- with likelihood ~ 0.06
#   7: decide-force -- with likelihood ~ 0.06
#   8: decide-socide -- with likelihood ~ 0.05
#   9: decide-continue -- with likelihood ~ 0.05
#   10: decride -- with likelihood ~ 0.05
#   11: decide-shortly -- with likelihood ~ 0.05
#   12: decide-short -- with likelihood ~ 0.04
#   13: decide-could -- with likelihood ~ 0.04
#   14: decide-forcide -- with likelihood ~ 0.04
#   15: decide-station -- with likelihood ~ 0.04
#
# wat
#   0: what -- with likelihood ~ 1.00
#   1: what's upsomething -- with likelihood ~ 0.03
#   2: what's upstaining -- with likelihood ~ 0.03
#   3: what's upstanding -- with likelihood ~ 0.03
#   4: what's up -- with likelihood ~ 0.02
#   5: what's upstagram -- with likelihood ~ 0.02
#   6: what's upsometimes -- with likelihood ~ 0.02
#   7: what's uplaining -- with likelihood ~ 0.02
#   8: what's upstagrammation -- with likelihood ~ 0.02
#   9: what's upshore -- with likelihood ~ 0.02
#   10: what's upstagramment -- with likelihood ~ 0.02
#   11: what's upstagrammating -- with likelihood ~ 0.01
#   12: what's upshort -- with likelihood ~ 0.01
#   13: what's upstagrammate -- with likelihood ~ 0.01
#   14: what's up that -- with likelihood ~ 0.01
#   15: what's upseason -- with likelihood ~ 0.01
#
# dey
#   0: they -- with likelihood ~ 1.00
#   1: they're -- with likelihood ~ 0.03
#   2: they'veloper -- with likelihood ~ 0.03
#   3: they've -- with likelihood ~ 0.03
#   4: they'veloped -- with likelihood ~ 0.03
#   5: they'veloping -- with likelihood ~ 0.02
#   6: they'velopment -- with likelihood ~ 0.02
#   7: theylight -- with likelihood ~ 0.02
#   8: they-they -- with likelihood ~ 0.02
#   9: they-though -- with likelihood ~ 0.02
#   10: they'd -- with likelihood ~ 0.02
#   11: they-thank you -- with likelihood ~ 0.02
#   12: they'll -- with likelihood ~ 0.02
#   13: they'velopen -- with likelihood ~ 0.02
#   14: theyhave -- with likelihood ~ 0.02
#   15: they't -- with likelihood ~ 0.02
#
# wanna
#   0: want to -- with likelihood ~ 1.00
#   1: wait to -- with likelihood ~ 0.10
#   2: waining to -- with likelihood ~ 0.07
#   3: want to going to -- with likelihood ~ 0.05
#   4: want to young to -- with likelihood ~ 0.05
#   5: want to want to -- with likelihood ~ 0.05
#   6: wont to -- with likelihood ~ 0.05
#   7: want towarding to -- with likelihood ~ 0.04
#   8: wain to -- with likelihood ~ 0.04
#   9: want toward to -- with likelihood ~ 0.04
#   10: want to fuck to -- with likelihood ~ 0.03
#   11: want to forgund to -- with likelihood ~ 0.03
#   12: waint to -- with likelihood ~ 0.03
#   13: what to -- with likelihood ~ 0.03
#   14: want to yourself -- with likelihood ~ 0.03
#   15: wrong to -- with likelihood ~ 0.03
#
# do
#   0: do -- with likelihood ~ 1.00
#   1: doughnut -- with likelihood ~ 0.04
#   2: domestic -- with likelihood ~ 0.02
#   3: doctrinution -- with likelihood ~ 0.02
#   4: doesn't -- with likelihood ~ 0.02
#   5: doctrinute -- with likelihood ~ 0.02
#   6: doctring -- with likelihood ~ 0.02
#   7: doctrinum -- with likelihood ~ 0.02
#   8: domesticration -- with likelihood ~ 0.02
#   9: though -- with likelihood ~ 0.02
#   10: dominate -- with likelihood ~ 0.02
#   11: doctrine -- with likelihood ~ 0.02
#   12: doctribute -- with likelihood ~ 0.01
#   13: doctrinumlation -- with likelihood ~ 0.01
#   14: domesticking -- with likelihood ~ 0.01
#   15: domestick -- with likelihood ~ 0.01

# %% [markdown]
# ### B. Process multiple sentences at once

# %%
sentences = [
    "fyrst sntnce",
    "scond one .",
    "and yet another one of them sentencesss"
]

tokens = [tokenizeRawTweetText(sentence) for sentence in sentences]

data = Data(tokens, args)
assembler = OutputAssembler(".", args, data.dataset)
model = Model(args, data).to(device)
model.eval()

for i, batch in enumerate(data.dataloader):
    batch = move_data_to_device(batch, device)
    output = model.generate(batch)
    assembler.step(output)

assembler.flush()

with open("outputs.txt") as f:
    for line in f.readlines():
        print(line.strip())
# Out:
# fyrst	first
# sntnce	sntnce
#
# scond	second
# one	one
# .	.
#
# and	and
# yet	yet
# another	another
# one	one
# of	of
# them	them
# sentencesss	sentences
